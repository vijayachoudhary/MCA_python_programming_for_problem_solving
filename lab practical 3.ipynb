# %%
num = int(input("Enter a number: "))
print("entered value:",num)
# Out:
# entered value: 123456

# %%
reversed_num = 0
temp = num
while temp != 0:
    remainder = temp % 10
    reversed_num = reversed_num * 10 + remainder
    temp //= 10
print("Reversed number:", reversed_num)
# Out:
# Reversed number: 654321
