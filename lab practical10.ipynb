# %%
import math 
num = int(input("enter a number:"))
print("entered number for find sqaure is :",num)
sqrt_value = math.sqrt(num)
print("square root of ",num,"is",sqrt_value)
# Out:
# entered number for find sqaure is : 64
# square root of  64 is 8.0

# %%
import math
num = int(input("enter a number:"))
print("entered number to find factorial is :",num)
result = math.factorial(num)
print(f"factorial of {num} is : {result}")
# Out:
# entered number to find factorial is : 5
# factorial of 5 is : 120

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

num = int(input("Enter a number: "))
print("Factorial of", num, "is", factorial(num))
# Out:
# Factorial of 5 is 120

# %%
from math import sqrt
num = float(input("enter a number:"))
result = sqrt(num)
print("sqaure root of ",num,"is",result)
# Out:
# sqaure root of  81.0 is 9.0

# %%
import math
base = int(input("enter base number:"))
power = int(input("enter power:"))
print("entered no is base :",base)
print("entered no is power:",power)
result = math.pow(base,power)
print("power =",result)
# Out:
# entered no is base : 5
# entered no is power: 6
# power = 15625.0
