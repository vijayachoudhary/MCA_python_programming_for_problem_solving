# %%
items = ["apple", "banana", "apple", "orange", "banana"]
print("entered items are:",items)
# Out:
# entered items are: ['apple', 'banana', 'apple', 'orange', 'banana']

# %%
unique_sorted_items = sorted(set(items))
print("Sorted unique items:", unique_sorted_items)
# Out:
# Sorted unique items: ['apple', 'banana', 'orange']
