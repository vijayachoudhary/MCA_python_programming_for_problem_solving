# %%
import random
students = ["vijaya","semi","pushpa","aspreet","aashi","billu"]
cr = random.choice(students)
print("class representative (CR:)",cr)
random.shuffle(students)
print("shuffled student list :",students)
# Out:
# class representative (CR:) vijaya
# shuffled student list : ['billu', 'semi', 'vijaya', 'aashi', 'pushpa', 'aspreet']
