# %%
string = input("Enter a string: ")
print("entered string:",string)
# Out:
# entered string: hello python programming

# %%
vowels = "aeiouAEIOU"
count = 0
for ch in string:
    if ch in vowels:
        count += 1
print(f"Number of vowels in the string: {count}")
# Out:
# Number of vowels in the string: 6
